# %% [markdown]
# # Columns to Keep/Delete
# County Statistics:
#     * county (primary key)
#     * state
#     * percentage20_Donald_Trump [percentage_votes_Donald_Trump]
#     * percentage20_Joe_Biden [percentage_votes_Joe_Biden]
#     * covid_cases [delete]
#     * covid_deaths [delete]
#     * TotalPop [delete]
#     * NEW COLUMN: Percent of cases by pop
#     * NEW COLUMN: Percent of deaths by pop
#     * Income per Capita
#     * Poverty
#     * Child Poverty
#     * Unemployment
#
# US County Sociohealth Data
#     * fips (county code)
#     * State
#     * County
#     * percent_fair_or_poor_health (skip)
#     * percent_uninshured
#     * percent_vaccinated
#     * high_school_graduation_rate
#     * percent_some_college
#     * violent_crime_rate
#     * life_expectancy

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Create filepaths and read csv files into dataframes
county_filepath = "datasources/county_statistics.csv"
sociohealth_filepath = "datasources/us_county_sociohealth_data.csv"

sociohealth_df = pd.read_csv(sociohealth_filepath)
county_stats_df = pd.read_csv(county_filepath)

# %%
# Delete unnecessary columns
county_stats_df = county_stats_df[['county','state','percentage20_Donald_Trump','percentage20_Joe_Biden',
                                   'cases','deaths','TotalPop','IncomePerCap','Poverty',
                                  'ChildPoverty','Unemployment']]
sociohealth_df = sociohealth_df[['fips', 'county', 'state',
                                 'percent_uninsured','percent_vaccinated','high_school_graduation_rate',
                                'percent_some_college','violent_crime_rate','life_expectancy']]

# %%
# Check columns are correct
county_stats_df.head()
# Out:
#       county state  percentage20_Donald_Trump  percentage20_Joe_Biden  \
# 0  Abbeville    SC                      0.661                   0.330
# 1     Acadia    LA                      0.795                   0.191
# 2   Accomack    VA                      0.542                   0.447
# 3        Ada    ID                      0.504                   0.465
# 4      Adair    IA                      0.697                   0.286
#
#      cases  deaths  TotalPop  IncomePerCap  Poverty  ChildPoverty  \
# 0    805.0    17.0   24788.0       19234.0     22.7          32.1
# 1   3182.0   102.0   62607.0       21591.0     21.5          27.6
# 2   1227.0    19.0   32840.0       24266.0     19.8          31.8
# 3  17451.0   181.0  435117.0       31642.0     11.8          13.1
# 4    222.0     1.0    7192.0       28861.0      9.5          12.1
#
#    Unemployment
# 0           9.4
# 1           8.9
# 2           5.4
# 3           4.3
# 4           3.0

# %%
# Check columns are correct
sociohealth_df.head()
# Out:
#     fips   county    state  percent_uninsured  percent_vaccinated  \
# 0  01001  Autauga  Alabama           8.721686                41.0
# 1  01003  Baldwin  Alabama          11.333404                44.0
# 2  01005  Barbour  Alabama          12.242792                37.0
# 3  01007     Bibb  Alabama          10.206253                38.0
# 4  01009   Blount  Alabama          13.360759                39.0
#
#    high_school_graduation_rate  percent_some_college  violent_crime_rate  \
# 0                    90.000000             62.009974          272.282220
# 1                    86.361577             67.371620          203.660396
# 2                    81.410256             34.857649          414.277861
# 3                    83.763838             44.137353           89.349126
# 4                    93.468795             53.361073          482.690611
#
#    life_expectancy
# 0        76.879477
# 1        78.450258
# 2        75.341935
# 3        73.571820
# 4        74.145826

# %%
# Check dataframe lengths before dropping N/A
print(f'County Stats: {len(county_stats_df)} Sociohealth Stats: {len(sociohealth_df)}')
# Out:
# County Stats: 4867 Sociohealth Stats: 3144

# %%
county_stats_df = county_stats_df.dropna()
sociohealth_df = sociohealth_df.dropna()

# %%
# Dataframe lengths after dropping N/A
print(f'County Stats: {len(county_stats_df)} Sociohealth Stats: {len(sociohealth_df)}')
# Out:
# County Stats: 3048 Sociohealth Stats: 2826

# %%
# Create percent of covid cases/deaths columns
county_stats_df['percentage_covid_cases'] = county_stats_df['cases'] / county_stats_df['TotalPop']
county_stats_df['percentage_covid_deaths'] = county_stats_df['deaths'] / county_stats_df['TotalPop']

county_stats_df.head()
# Out:
#       county state  percentage20_Donald_Trump  percentage20_Joe_Biden  \
# 0  Abbeville    SC                      0.661                   0.330
# 1     Acadia    LA                      0.795                   0.191
# 2   Accomack    VA                      0.542                   0.447
# 3        Ada    ID                      0.504                   0.465
# 4      Adair    IA                      0.697                   0.286
#
#      cases  deaths  TotalPop  IncomePerCap  Poverty  ChildPoverty  \
# 0    805.0    17.0   24788.0       19234.0     22.7          32.1
# 1   3182.0   102.0   62607.0       21591.0     21.5          27.6
# 2   1227.0    19.0   32840.0       24266.0     19.8          31.8
# 3  17451.0   181.0  435117.0       31642.0     11.8          13.1
# 4    222.0     1.0    7192.0       28861.0      9.5          12.1
#
#    Unemployment  percentage_covid_cases  percentage_covid_deaths
# 0           9.4                0.032475                 0.000686
# 1           8.9                0.050825                 0.001629
# 2           5.4                0.037363                 0.000579
# 3           4.3                0.040106                 0.000416
# 4           3.0                0.030868                 0.000139

# %%
# Delete cases/deaths columns
county_stats_df = county_stats_df.drop(columns = ['cases', 'deaths', 'TotalPop'])
county_stats_df.head()
# Out:
#       county state  percentage20_Donald_Trump  percentage20_Joe_Biden  \
# 0  Abbeville    SC                      0.661                   0.330
# 1     Acadia    LA                      0.795                   0.191
# 2   Accomack    VA                      0.542                   0.447
# 3        Ada    ID                      0.504                   0.465
# 4      Adair    IA                      0.697                   0.286
#
#    IncomePerCap  Poverty  ChildPoverty  Unemployment  percentage_covid_cases  \
# 0       19234.0     22.7          32.1           9.4                0.032475
# 1       21591.0     21.5          27.6           8.9                0.050825
# 2       24266.0     19.8          31.8           5.4                0.037363
# 3       31642.0     11.8          13.1           4.3                0.040106
# 4       28861.0      9.5          12.1           3.0                0.030868
#
#    percentage_covid_deaths
# 0                 0.000686
# 1                 0.001629
# 2                 0.000579
# 3                 0.000416
# 4                 0.000139

# %%
# Rename columns to match sql database
county_stats_df = county_stats_df.rename(columns = {
    'percentage20_Donald_Trump':'percentage_votes_Donald_Trump',
    'percentage20_Joe_Biden':'percentage_votes_Joe_Biden',
    'IncomePerCap':'income_per_capita',
    'Poverty':'poverty_rate',
    'ChildPoverty':'child_poverty_rate',
    'Unemployment':'unemployment_rate' 
})

# rearranging columns to fit sql tables
county_stats_df = county_stats_df[['county', 'state', 'percentage_votes_Donald_Trump', 'percentage_votes_Joe_Biden',
                                    'percentage_covid_cases', 'percentage_covid_deaths', 'income_per_capita',
                                    'poverty_rate', 'child_poverty_rate', 'unemployment_rate']]
county_stats_df.head()
# Out:
#       county state  percentage_votes_Donald_Trump  percentage_votes_Joe_Biden  \
# 0  Abbeville    SC                          0.661                       0.330
# 1     Acadia    LA                          0.795                       0.191
# 2   Accomack    VA                          0.542                       0.447
# 3        Ada    ID                          0.504                       0.465
# 4      Adair    IA                          0.697                       0.286
#
#    percentage_covid_cases  percentage_covid_deaths  income_per_capita  \
# 0                0.032475                 0.000686            19234.0
# 1                0.050825                 0.001629            21591.0
# 2                0.037363                 0.000579            24266.0
# 3                0.040106                 0.000416            31642.0
# 4                0.030868                 0.000139            28861.0
#
#    poverty_rate  child_poverty_rate  unemployment_rate
# 0          22.7                32.1                9.4
# 1          21.5                27.6                8.9
# 2          19.8                31.8                5.4
# 3          11.8                13.1                4.3
# 4           9.5                12.1                3.0

# %%
sociohealth_df.head()
# Out:
#     fips   county    state  percent_uninsured  percent_vaccinated  \
# 0  01001  Autauga  Alabama           8.721686                41.0
# 1  01003  Baldwin  Alabama          11.333404                44.0
# 2  01005  Barbour  Alabama          12.242792                37.0
# 3  01007     Bibb  Alabama          10.206253                38.0
# 4  01009   Blount  Alabama          13.360759                39.0
#
#    high_school_graduation_rate  percent_some_college  violent_crime_rate  \
# 0                    90.000000             62.009974          272.282220
# 1                    86.361577             67.371620          203.660396
# 2                    81.410256             34.857649          414.277861
# 3                    83.763838             44.137353           89.349126
# 4                    93.468795             53.361073          482.690611
#
#    life_expectancy
# 0        76.879477
# 1        78.450258
# 2        75.341935
# 3        73.571820
# 4        74.145826

# %%
# Rename columns as before
sociohealth_df = sociohealth_df.rename(columns = {
    'fips':'fips_code',
    'percent_uninsured':'percentage_uninsured',
    'percent_vaccinated':'percentage_vaccinated',
    'percent_some_college':'percentage_some_college'
})
sociohealth_df.head()
# Out:
#   fips_code   county    state  percentage_uninsured  percentage_vaccinated  \
# 0     01001  Autauga  Alabama              8.721686                   41.0
# 1     01003  Baldwin  Alabama             11.333404                   44.0
# 2     01005  Barbour  Alabama             12.242792                   37.0
# 3     01007     Bibb  Alabama             10.206253                   38.0
# 4     01009   Blount  Alabama             13.360759                   39.0
#
#    high_school_graduation_rate  percentage_some_college  violent_crime_rate  \
# 0                    90.000000                62.009974          272.282220
# 1                    86.361577                67.371620          203.660396
# 2                    81.410256                34.857649          414.277861
# 3                    83.763838                44.137353           89.349126
# 4                    93.468795                53.361073          482.690611
#
#    life_expectancy
# 0        76.879477
# 1        78.450258
# 2        75.341935
# 3        73.571820
# 4        74.145826

# %%
rds_connection_string = "postgres:postgres@localhost:5432/county_db"
engine = create_engine(f"postgresql://{rds_connection_string}")

# %%
engine.table_names()
# Out:
# ['county_statistics', 'county_sociohealth_data']

# %%
# dropped rows with Alaska from sociohealth_df because other state does not have Alaska in data
sociohealth_df = sociohealth_df.loc[sociohealth_df['state'] != 'Alaska']

# %%
county_stats_df['state'].unique()
# Out:
# array(['SC', 'LA', 'VA', 'ID', 'IA', 'KY', 'MO', 'OK', 'CO', 'IL', 'IN',
#        'MS', 'ND', 'NE', 'OH', 'PA', 'WA', 'WI', 'VT', 'MN', 'FL', 'NC',
#        'CA', 'NY', 'WY', 'MI', 'MD', 'KS', 'TN', 'TX', 'AZ', 'GA', 'AR',
#        'NJ', 'SD', 'AL', 'OR', 'WV', 'MA', 'UT', 'MT', 'NM', 'RI', 'NH',
#        'NV', 'ME', 'DC', 'CT', 'HI', 'DE'], dtype=object)

# %%
abbreviation_to_full = {"AL":"Alabama", "AZ":"Arizona","AR":"Arkansas","CA":"California",
                             "CO":"Colorado","CT":"Connecticut", "DC": "District of Columbia", 
                             "DE":"Delaware","FL":"Florida","GA":"Georgia","HI":"Hawaii",
                             "ID":"Idaho","IL":"Illinois","IN":"Indiana","IA":"Iowa",
                             "KS":"Kansas","KY":"Kentucky","LA":"Louisiana","ME":"Maine",
                             "MD":"Maryland","MA":"Massachusetts","MI":"Michigan",
                             "MN":"Minnesota","MS":"Mississippi","MO":"Missouri","MT":"Montana",
                             "NE":"Nebraska","NV":"Nevada","NH":"New Hampshire","NJ":"New Jersey",
                             "NM":"New Mexico","NY":"New York","NC":"North Carolina",
                             "ND":"North Dakota","OH":"Ohio","OK":"Oklahoma","OR":"Oregon",
                             "PA":"Pennsylvania","RI":"Rhode Island","SC":"South Carolina",
                             "SD":"South Dakota","TN":"Tennessee","TX":"Texas","UT":"Utah",
                             "VT":"Vermont","VA":"Virginia","WA":"Washington","WV":"West Virginia",
                             "WI":"Wisconsin","WY":"Wyoming"}

# change abbreviated state names in county_stats.df to full name
county_stats_df['state'] = ([abbreviation_to_full[i] for i in county_stats_df['state']])

# %%
county_stats_df = county_stats_df.reset_index(drop=True)
sociohealth_df = sociohealth_df.reset_index(drop=True)

# %%
# create dictionaries with each county name as key and append list of states that have that county
county_stats_counties = {}
sociohealth_counties = {}

for i in range(len(county_stats_df)):
    if (county_stats_df.loc[i, 'county'] in county_stats_counties):
        county_stats_counties[county_stats_df.loc[i, 'county']].append(county_stats_df.loc[i, 'state'])
    else:
        county_stats_counties[county_stats_df.loc[i, 'county']] = [county_stats_df.loc[i, 'state']]

for i in range(len(sociohealth_df)):
    if (sociohealth_df.loc[i, 'county'] in sociohealth_counties):
        sociohealth_counties[sociohealth_df.loc[i, 'county']].append(sociohealth_df.loc[i, 'state'])
    else:
        sociohealth_counties[sociohealth_df.loc[i, 'county']] = [sociohealth_df.loc[i, 'state']]

# %%
sociohealth_counties
# Out:
# {'Autauga': ['Alabama'],
#  'Baldwin': ['Alabama', 'Georgia'],
#  'Barbour': ['Alabama', 'West Virginia'],
#  'Bibb': ['Alabama', 'Georgia'],
#  'Blount': ['Alabama', 'Tennessee'],
#  'Bullock': ['Alabama'],
#  'Butler': ['Alabama',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Missouri',
#   'Nebraska',
#   'Ohio',
#   'Pennsylvania'],
#  'Calhoun': ['Alabama',
#   'Arkansas',
#   'Florida',
#   'Georgia',
#   'Iowa',
#   'Michigan',
#   'South Carolina',
#   'Texas',
#   'West Virginia'],
#  'Chambers': ['Alabama', 'Texas'],
#  'Cherokee': ['Alabama',
#   'Georgia',
#   'Iowa',
#   'Kansas',
#   'North Carolina',
#   'Oklahoma',
#   'South Carolina',
#   'Texas'],
#  'Chilton': ['Alabama'],
#  'Choctaw': ['Alabama', 'Mississippi', 'Oklahoma'],
#  'Clarke': ['Alabama', 'Georgia', 'Iowa', 'Virginia'],
#  'Clay': ['Alabama',
#   'Arkansas',
#   'Florida',
#   'Illinois',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Minnesota',
#   'Mississippi',
#   'Nebraska',
#   'North Carolina',
#   'South Dakota',
#   'Tennessee',
#   'Texas'],
#  'Cleburne': ['Alabama', 'Arkansas'],
#  'Coffee': ['Alabama', 'Georgia', 'Tennessee'],
#  'Colbert': ['Alabama'],
#  'Conecuh': ['Alabama'],
#  'Coosa': ['Alabama'],
#  'Covington': ['Alabama'],
#  'Crenshaw': ['Alabama'],
#  'Cullman': ['Alabama'],
#  'Dale': ['Alabama'],
#  'Dallas': ['Alabama', 'Arkansas', 'Iowa', 'Missouri', 'Texas'],
#  'DeKalb': ['Alabama',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Missouri',
#   'Tennessee'],
#  'Elmore': ['Alabama', 'Idaho'],
#  'Escambia': ['Alabama', 'Florida'],
#  'Etowah': ['Alabama'],
#  'Franklin': ['Alabama',
#   'Arkansas',
#   'Florida',
#   'Georgia',
#   'Idaho',
#   'Illinois',
#   'Indiana',
#   'Kansas',
#   'Kentucky',
#   'Louisiana',
#   'Maine',
#   'Massachusetts',
#   'Missouri',
#   'Nebraska',
#   'New York',
#   'North Carolina',
#   'Ohio',
#   'Pennsylvania',
#   'Tennessee',
#   'Texas',
#   'Vermont',
#   'Virginia',
#   'Washington'],
#  'Geneva': ['Alabama'],
#  'Greene': ['Alabama',
#   'Arkansas',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Mississippi',
#   'Missouri',
#   'New York',
#   'Ohio',
#   'Pennsylvania',
#   'Tennessee',
#   'Virginia'],
#  'Hale': ['Alabama', 'Texas'],
#  'Henry': ['Alabama',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kentucky',
#   'Missouri',
#   'Ohio',
#   'Tennessee',
#   'Virginia'],
#  'Houston': ['Alabama', 'Georgia', 'Minnesota', 'Tennessee', 'Texas'],
#  'Jackson': ['Alabama',
#   'Arkansas',
#   'Florida',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Louisiana',
#   'Michigan',
#   'Minnesota',
#   'Mississippi',
#   'Missouri',
#   'North Carolina',
#   'Ohio',
#   'Oklahoma',
#   'Oregon',
#   'Tennessee',
#   'Texas',
#   'West Virginia',
#   'Wisconsin'],
#  'Jefferson': ['Alabama',
#   'Arkansas',
#   'Colorado',
#   'Florida',
#   'Georgia',
#   'Idaho',
#   'Illinois',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Louisiana',
#   'Mississippi',
#   'Missouri',
#   'Montana',
#   'Nebraska',
#   'New York',
#   'Ohio',
#   'Oregon',
#   'Pennsylvania',
#   'Tennessee',
#   'Texas',
#   'Washington',
#   'West Virginia',
#   'Wisconsin'],
#  'Lamar': ['Alabama', 'Georgia', 'Mississippi', 'Texas'],
#  'Lauderdale': ['Alabama', 'Mississippi', 'Tennessee'],
#  'Lawrence': ['Alabama',
#   'Arkansas',
#   'Illinois',
#   'Indiana',
#   'Kentucky',
#   'Missouri',
#   'Ohio',
#   'Pennsylvania',
#   'South Dakota',
#   'Tennessee'],
#  'Lee': ['Alabama',
#   'Arkansas',
#   'Florida',
#   'Georgia',
#   'Illinois',
#   'Iowa',
#   'Kentucky',
#   'North Carolina',
#   'South Carolina',
#   'Texas',
#   'Virginia'],
#  'Limestone': ['Alabama', 'Texas'],
#  'Lowndes': ['Alabama', 'Georgia'],
#  'Macon': ['Alabama',
#   'Georgia',
#   'Illinois',
#   'Missouri',
#   'North Carolina',
#   'Tennessee'],
#  'Madison': ['Alabama',
#   'Arkansas',
#   'Florida',
#   'Georgia',
#   'Idaho',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kentucky',
#   'Louisiana',
#   'Mississippi',
#   'Missouri',
#   'Montana',
#   'Nebraska',
#   'New York',
#   'North Carolina',
#   'Ohio',
#   'Tennessee',
#   'Texas',
#   'Virginia'],
#  'Marengo': ['Alabama'],
#  'Marion': ['Alabama',
#   'Arkansas',
#   'Florida',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Mississippi',
#   'Missouri',
#   'Ohio',
#   'Oregon',
#   'South Carolina',
#   'Tennessee',
#   'Texas',
#   'West Virginia'],
#  'Marshall': ['Alabama',
#   'Illinois',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Minnesota',
#   'Mississippi',
#   'Oklahoma',
#   'South Dakota',
#   'Tennessee',
#   'West Virginia'],
#  'Mobile': ['Alabama'],
#  'Monroe': ['Alabama',
#   'Arkansas',
#   'Florida',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kentucky',
#   'Michigan',
#   'Missouri',
#   'New York',
#   'Ohio',
#   'Pennsylvania',
#   'Tennessee',
#   'West Virginia',
#   'Wisconsin'],
#  'Montgomery': ['Alabama',
#   'Arkansas',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Maryland',
#   'Missouri',
#   'New York',
#   'North Carolina',
#   'Ohio',
#   'Pennsylvania',
#   'Tennessee',
#   'Texas',
#   'Virginia'],
#  'Morgan': ['Alabama',
#   'Colorado',
#   'Georgia',
#   'Illinois',
#   'Kentucky',
#   'Missouri',
#   'Ohio',
#   'Tennessee',
#   'West Virginia'],
#  'Perry': ['Alabama',
#   'Arkansas',
#   'Illinois',
#   'Kentucky',
#   'Missouri',
#   'Ohio',
#   'Pennsylvania',
#   'Tennessee'],
#  'Pickens': ['Alabama', 'Georgia', 'South Carolina'],
#  'Pike': ['Alabama',
#   'Arkansas',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Kentucky',
#   'Missouri',
#   'Ohio',
#   'Pennsylvania'],
#  'Randolph': ['Alabama',
#   'Arkansas',
#   'Georgia',
#   'Illinois',
#   'Missouri',
#   'North Carolina',
#   'West Virginia'],
#  'Russell': ['Alabama', 'Kansas', 'Kentucky', 'Virginia'],
#  'St. Clair': ['Alabama', 'Illinois', 'Michigan', 'Missouri'],
#  'Shelby': ['Alabama',
#   'Illinois',
#   'Indiana',
#   'Kentucky',
#   'Missouri',
#   'Ohio',
#   'Tennessee',
#   'Texas'],
#  'Sumter': ['Alabama', 'Florida', 'Georgia', 'South Carolina'],
#  'Talladega': ['Alabama'],
#  'Tallapoosa': ['Alabama'],
#  'Tuscaloosa': ['Alabama'],
#  'Walker': ['Alabama', 'Georgia', 'Texas'],
#  'Washington': ['Alabama',
#   'Arkansas',
#   'Colorado',
#   'Florida',
#   'Georgia',
#   'Idaho',
#   'Illinois',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Louisiana',
#   'Maryland',
#   'Minnesota',
#   'Mississippi',
#   'Missouri',
#   'Nebraska',
#   'New York',
#   'North Carolina',
#   'Ohio',
#   'Oklahoma',
#   'Oregon',
#   'Pennsylvania',
#   'Rhode Island',
#   'Tennessee',
#   'Texas',
#   'Utah',
#   'Vermont',
#   'Virginia',
#   'Wisconsin'],
#  'Wilcox': ['Alabama', 'Georgia'],
#  'Winston': ['Alabama'],
#  'Apache': ['Arizona'],
#  'Cochise': ['Arizona'],
#  'Coconino': ['Arizona'],
#  'Gila': ['Arizona'],
#  'Graham': ['Arizona', 'Kansas', 'North Carolina'],
#  'Greenlee': ['Arizona'],
#  'La Paz': ['Arizona'],
#  'Maricopa': ['Arizona'],
#  'Mohave': ['Arizona'],
#  'Navajo': ['Arizona'],
#  'Pima': ['Arizona'],
#  'Pinal': ['Arizona'],
#  'Santa Cruz': ['Arizona', 'California'],
#  'Yavapai': ['Arizona'],
#  'Yuma': ['Arizona', 'Colorado'],
#  'Arkansas': ['Arkansas'],
#  'Ashley': ['Arkansas'],
#  'Baxter': ['Arkansas'],
#  'Benton': ['Arkansas',
#   'Minnesota',
#   'Missouri',
#   'Oregon',
#   'Tennessee',
#   'Washington'],
#  'Boone': ['Arkansas',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kentucky',
#   'Missouri',
#   'West Virginia'],
#  'Bradley': ['Arkansas', 'Tennessee'],
#  'Carroll': ['Arkansas',
#   'Georgia',
#   'Illinois',
#   'Iowa',
#   'Kentucky',
#   'Maryland',
#   'Missouri',
#   'New Hampshire',
#   'Tennessee',
#   'Virginia'],
#  'Chicot': ['Arkansas'],
#  'Clark': ['Arkansas',
#   'Illinois',
#   'Indiana',
#   'Kansas',
#   'Kentucky',
#   'Missouri',
#   'Nevada',
#   'Ohio',
#   'South Dakota',
#   'Washington',
#   'Wisconsin'],
#  'Cleveland': ['Arkansas', 'North Carolina', 'Oklahoma'],
#  'Columbia': ['Arkansas',
#   'Florida',
#   'Georgia',
#   'New York',
#   'Oregon',
#   'Pennsylvania',
#   'Washington',
#   'Wisconsin'],
#  'Conway': ['Arkansas'],
#  'Craighead': ['Arkansas'],
#  'Crawford': ['Arkansas',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kansas',
#   'Michigan',
#   'Missouri',
#   'Ohio',
#   'Pennsylvania',
#   'Wisconsin'],
#  'Crittenden': ['Arkansas', 'Kentucky'],
#  'Cross': ['Arkansas'],
#  'Desha': ['Arkansas'],
#  'Drew': ['Arkansas'],
#  'Faulkner': ['Arkansas'],
#  'Fulton': ['Arkansas',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Kentucky',
#   'New York',
#   'Ohio',
#   'Pennsylvania'],
#  'Garland': ['Arkansas'],
#  'Grant': ['Arkansas',
#   'Indiana',
#   'Kansas',
#   'Kentucky',
#   'Louisiana',
#   'Minnesota',
#   'Oregon',
#   'Washington',
#   'West Virginia',
#   'Wisconsin'],
#  'Hempstead': ['Arkansas'],
#  'Hot Spring': ['Arkansas'],
#  'Howard': ['Arkansas', 'Indiana', 'Iowa', 'Maryland', 'Missouri', 'Texas'],
#  'Independence': ['Arkansas'],
#  'Izard': ['Arkansas'],
#  'Johnson': ['Arkansas',
#   'Georgia',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Missouri',
#   'Nebraska',
#   'Tennessee',
#   'Texas',
#   'Wyoming'],
#  'Lafayette': ['Arkansas', 'Florida', 'Louisiana', 'Missouri', 'Wisconsin'],
#  'Lincoln': ['Arkansas',
#   'Colorado',
#   'Georgia',
#   'Idaho',
#   'Kansas',
#   'Kentucky',
#   'Louisiana',
#   'Minnesota',
#   'Mississippi',
#   'Missouri',
#   'Montana',
#   'Nebraska',
#   'Nevada',
#   'New Mexico',
#   'North Carolina',
#   'Oklahoma',
#   'Oregon',
#   'South Dakota',
#   'Tennessee',
#   'Washington',
#   'Wisconsin',
#   'Wyoming'],
#  'Little River': ['Arkansas'],
#  'Logan': ['Arkansas',
#   'Colorado',
#   'Illinois',
#   'Kansas',
#   'Kentucky',
#   'Ohio',
#   'Oklahoma',
#   'West Virginia'],
#  'Lonoke': ['Arkansas'],
#  'Miller': ['Arkansas', 'Georgia', 'Missouri'],
#  'Mississippi': ['Arkansas', 'Missouri'],
#  'Nevada': ['Arkansas', 'California'],
#  'Newton': ['Arkansas', 'Georgia', 'Indiana', 'Missouri', 'Texas'],
#  'Ouachita': ['Arkansas', 'Louisiana'],
#  'Phillips': ['Arkansas', 'Colorado', 'Kansas', 'Montana'],
#  'Poinsett': ['Arkansas'],
#  'Polk': ['Arkansas',
#   'Florida',
#   'Georgia',
#   'Iowa',
#   'Minnesota',
#   'Missouri',
#   'Nebraska',
#   'North Carolina',
#   'Oregon',
#   'Tennessee',
#   'Texas',
#   'Wisconsin'],
#  'Pope': ['Arkansas', 'Minnesota'],
#  'Prairie': ['Arkansas'],
#  'Pulaski': ['Arkansas',
#   'Georgia',
#   'Illinois',
#   'Kentucky',
#   'Missouri',
#   'Virginia'],
#  'St. Francis': ['Arkansas'],
#  'Saline': ['Arkansas', 'Illinois', 'Kansas', 'Missouri', 'Nebraska'],
#  'Scott': ['Arkansas',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kansas',
#   'Kentucky',
#   'Minnesota',
#   'Mississippi',
#   'Missouri',
#   'Tennessee',
#   'Virginia'],
#  'Searcy': ['Arkansas'],
#  'Sebastian': ['Arkansas'],
#  'Sevier': ['Arkansas', 'Tennessee', 'Utah'],
#  'Stone': ['Arkansas', 'Mississippi', 'Missouri'],
#  'Union': ['Arkansas',
#   'Florida',
#   'Georgia',
#   'Illinois',
#   'Iowa',
#   'Kentucky',
#   'Louisiana',
#   'New Jersey',
#   'New Mexico',
#   'North Carolina',
#   'Ohio',
#   'Oregon',
#   'Pennsylvania',
#   'South Carolina',
#   'South Dakota',
#   'Tennessee'],
#  'Van Buren': ['Arkansas', 'Iowa', 'Michigan', 'Tennessee'],
#  'White': ['Arkansas', 'Georgia', 'Illinois', 'Indiana', 'Tennessee'],
#  'Woodruff': ['Arkansas'],
#  'Yell': ['Arkansas'],
#  'Alameda': ['California'],
#  'Amador': ['California'],
#  'Butte': ['California', 'Idaho', 'South Dakota'],
#  'Calaveras': ['California'],
#  'Colusa': ['California'],
#  'Contra Costa': ['California'],
#  'Del Norte': ['California'],
#  'El Dorado': ['California'],
#  'Fresno': ['California'],
#  'Glenn': ['California'],
#  'Humboldt': ['California', 'Iowa', 'Nevada'],
#  'Imperial': ['California'],
#  'Inyo': ['California'],
#  'Kern': ['California'],
#  'Kings': ['California', 'New York'],
#  'Lake': ['California',
#   'Colorado',
#   'Florida',
#   'Illinois',
#   'Indiana',
#   'Michigan',
#   'Minnesota',
#   'Montana',
#   'Ohio',
#   'South Dakota',
#   'Tennessee'],
#  'Lassen': ['California'],
#  'Los Angeles': ['California'],
#  'Madera': ['California'],
#  'Marin': ['California'],
#  'Mariposa': ['California'],
#  'Mendocino': ['California'],
#  'Merced': ['California'],
#  'Modoc': ['California'],
#  'Mono': ['California'],
#  'Monterey': ['California'],
#  'Napa': ['California'],
#  'Orange': ['California',
#   'Florida',
#   'New York',
#   'North Carolina',
#   'Texas',
#   'Vermont',
#   'Virginia'],
#  'Placer': ['California'],
#  'Plumas': ['California'],
#  'Riverside': ['California'],
#  'Sacramento': ['California'],
#  'San Benito': ['California'],
#  'San Bernardino': ['California'],
#  'San Diego': ['California'],
#  'San Francisco': ['California'],
#  'San Joaquin': ['California'],
#  'San Luis Obispo': ['California'],
#  'San Mateo': ['California'],
#  'Santa Barbara': ['California'],
#  'Santa Clara': ['California'],
#  'Shasta': ['California'],
#  'Sierra': ['California', 'New Mexico'],
#  'Siskiyou': ['California'],
#  'Solano': ['California'],
#  'Sonoma': ['California'],
#  'Stanislaus': ['California'],
#  'Sutter': ['California'],
#  'Tehama': ['California'],
#  'Trinity': ['California', 'Texas'],
#  'Tulare': ['California'],
#  'Tuolumne': ['California'],
#  'Ventura': ['California'],
#  'Yolo': ['California'],
#  'Yuba': ['California'],
#  'Adams': ['Colorado',
#   'Idaho',
#   'Illinois',
#   'Iowa',
#   'Mississippi',
#   'Nebraska',
#   'Ohio',
#   'Pennsylvania',
#   'Washington',
#   'Wisconsin'],
#  'Arapahoe': ['Colorado'],
#  'Archuleta': ['Colorado'],
#  'Baca': ['Colorado'],
#  'Bent': ['Colorado'],
#  'Boulder': ['Colorado'],
#  'Chaffee': ['Colorado'],
#  'Cheyenne': ['Colorado', 'Kansas', 'Nebraska'],
#  'Clear Creek': ['Colorado'],
#  'Conejos': ['Colorado'],
#  'Costilla': ['Colorado'],
#  'Crowley': ['Colorado'],
#  'Custer': ['Colorado',
#   'Idaho',
#   'Montana',
#   'Nebraska',
#   'Oklahoma',
#   'South Dakota'],
#  'Delta': ['Colorado', 'Michigan', 'Texas'],
#  'Denver': ['Colorado'],
#  'Dolores': ['Colorado'],
#  'Douglas': ['Colorado',
#   'Georgia',
#   'Illinois',
#   'Kansas',
#   'Minnesota',
#   'Missouri',
#   'Nebraska',
#   'Nevada',
#   'Oregon',
#   'South Dakota',
#   'Washington',
#   'Wisconsin'],
#  'Eagle': ['Colorado'],
#  'Elbert': ['Colorado', 'Georgia'],
#  'El Paso': ['Colorado', 'Texas'],
#  'Fremont': ['Colorado', 'Idaho', 'Iowa', 'Wyoming'],
#  'Garfield': ['Colorado', 'Nebraska', 'Oklahoma', 'Washington'],
#  'Gilpin': ['Colorado'],
#  'Grand': ['Colorado', 'Utah'],
#  'Gunnison': ['Colorado'],
#  'Huerfano': ['Colorado'],
#  'Kit Carson': ['Colorado'],
#  'La Plata': ['Colorado'],
#  'Larimer': ['Colorado'],
#  'Las Animas': ['Colorado'],
#  'Mesa': ['Colorado'],
#  'Moffat': ['Colorado'],
#  'Montezuma': ['Colorado'],
#  'Montrose': ['Colorado'],
#  'Otero': ['Colorado', 'New Mexico'],
#  'Ouray': ['Colorado'],
#  'Park': ['Colorado', 'Montana', 'Wyoming'],
#  'Pitkin': ['Colorado'],
#  'Prowers': ['Colorado'],
#  'Pueblo': ['Colorado'],
#  'Rio Blanco': ['Colorado'],
#  'Rio Grande': ['Colorado'],
#  'Routt': ['Colorado'],
#  'Saguache': ['Colorado'],
#  'San Miguel': ['Colorado', 'New Mexico'],
#  'Sedgwick': ['Colorado', 'Kansas'],
#  'Summit': ['Colorado', 'Ohio', 'Utah'],
#  'Teller': ['Colorado'],
#  'Weld': ['Colorado'],
#  'Fairfield': ['Connecticut', 'Ohio', 'South Carolina'],
#  'Hartford': ['Connecticut'],
#  'Litchfield': ['Connecticut'],
#  'Middlesex': ['Connecticut', 'Massachusetts', 'New Jersey', 'Virginia'],
#  'New Haven': ['Connecticut'],
#  'New London': ['Connecticut'],
#  'Kent': ['Delaware', 'Maryland', 'Michigan', 'Rhode Island'],
#  'New Castle': ['Delaware'],
#  'Sussex': ['Delaware', 'New Jersey', 'Virginia'],
#  'District of Columbia': ['District of Columbia'],
#  'Alachua': ['Florida'],
#  'Baker': ['Florida', 'Oregon'],
#  'Bay': ['Florida', 'Michigan'],
#  'Bradford': ['Florida', 'Pennsylvania'],
#  'Brevard': ['Florida'],
#  'Broward': ['Florida'],
#  'Charlotte': ['Florida', 'Virginia'],
#  'Citrus': ['Florida'],
#  'Collier': ['Florida'],
#  'DeSoto': ['Florida', 'Mississippi'],
#  'Dixie': ['Florida'],
#  'Duval': ['Florida', 'Texas'],
#  'Flagler': ['Florida'],
#  'Gadsden': ['Florida'],
#  'Gilchrist': ['Florida'],
#  'Glades': ['Florida'],
#  'Gulf': ['Florida'],
#  'Hamilton': ['Florida',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kansas',
#   'Nebraska',
#   'New York',
#   'Ohio',
#   'Tennessee',
#   'Texas'],
#  'Hardee': ['Florida'],
#  'Hendry': ['Florida'],
#  'Hernando': ['Florida'],
#  'Highlands': ['Florida'],
#  'Hillsborough': ['Florida', 'New Hampshire'],
#  'Holmes': ['Florida', 'Ohio'],
#  'Indian River': ['Florida'],
#  'Leon': ['Florida', 'Texas'],
#  'Levy': ['Florida'],
#  'Liberty': ['Florida', 'Georgia', 'Montana', 'Texas'],
#  'Manatee': ['Florida'],
#  'Martin': ['Florida', 'Kentucky', 'Minnesota', 'North Carolina', 'Texas'],
#  'Miami-Dade': ['Florida'],
#  'Nassau': ['Florida', 'New York'],
#  'Okaloosa': ['Florida'],
#  'Okeechobee': ['Florida'],
#  'Osceola': ['Florida', 'Iowa', 'Michigan'],
#  'Palm Beach': ['Florida'],
#  'Pasco': ['Florida'],
#  'Pinellas': ['Florida'],
#  'Putnam': ['Florida',
#   'Georgia',
#   'Illinois',
#   'Missouri',
#   'New York',
#   'Ohio',
#   'Tennessee',
#   'West Virginia'],
#  'St. Johns': ['Florida'],
#  'St. Lucie': ['Florida'],
#  'Santa Rosa': ['Florida'],
#  'Sarasota': ['Florida'],
#  'Seminole': ['Florida', 'Georgia', 'Oklahoma'],
#  'Suwannee': ['Florida'],
#  'Taylor': ['Florida', 'Georgia', 'Iowa', 'Kentucky', 'Texas', 'Wisconsin'],
#  'Volusia': ['Florida'],
#  'Wakulla': ['Florida'],
#  'Walton': ['Florida', 'Georgia'],
#  'Appling': ['Georgia'],
#  'Banks': ['Georgia'],
#  'Barrow': ['Georgia'],
#  'Bartow': ['Georgia'],
#  'Ben Hill': ['Georgia'],
#  'Berrien': ['Georgia', 'Michigan'],
#  'Bleckley': ['Georgia'],
#  'Brantley': ['Georgia'],
#  'Brooks': ['Georgia', 'Texas'],
#  'Bryan': ['Georgia', 'Oklahoma'],
#  'Bulloch': ['Georgia'],
#  'Burke': ['Georgia', 'North Carolina'],
#  'Butts': ['Georgia'],
#  'Camden': ['Georgia', 'Missouri', 'New Jersey', 'North Carolina'],
#  'Catoosa': ['Georgia'],
#  'Charlton': ['Georgia'],
#  'Chatham': ['Georgia', 'North Carolina'],
#  'Chattahoochee': ['Georgia'],
#  'Chattooga': ['Georgia'],
#  'Clayton': ['Georgia', 'Iowa'],
#  'Clinch': ['Georgia'],
#  'Cobb': ['Georgia'],
#  'Cook': ['Georgia', 'Illinois', 'Minnesota'],
#  'Coweta': ['Georgia'],
#  'Crisp': ['Georgia'],
#  'Dade': ['Georgia', 'Missouri'],
#  'Dawson': ['Georgia', 'Montana', 'Nebraska', 'Texas'],
#  'Decatur': ['Georgia', 'Kansas', 'Tennessee'],
#  'Dodge': ['Georgia', 'Minnesota', 'Nebraska', 'Wisconsin'],
#  'Dooly': ['Georgia'],
#  'Dougherty': ['Georgia'],
#  'Early': ['Georgia'],
#  'Echols': ['Georgia'],
#  'Effingham': ['Georgia', 'Illinois'],
#  'Emanuel': ['Georgia'],
#  'Evans': ['Georgia'],
#  'Fannin': ['Georgia', 'Texas'],
#  'Fayette': ['Georgia',
#   'Illinois',
#   'Iowa',
#   'Kentucky',
#   'Ohio',
#   'Pennsylvania',
#   'Tennessee',
#   'Texas',
#   'West Virginia'],
#  'Floyd': ['Georgia', 'Indiana', 'Iowa', 'Kentucky', 'Texas', 'Virginia'],
#  'Forsyth': ['Georgia', 'North Carolina'],
#  'Gilmer': ['Georgia', 'West Virginia'],
#  'Glascock': ['Georgia'],
#  'Glynn': ['Georgia'],
#  'Gordon': ['Georgia'],
#  'Grady': ['Georgia', 'Oklahoma'],
#  'Gwinnett': ['Georgia'],
#  'Habersham': ['Georgia'],
#  'Hall': ['Georgia', 'Nebraska', 'Texas'],
#  'Hancock': ['Georgia',
#   'Illinois',
#   'Indiana',
#   'Iowa',
#   'Kentucky',
#   'Maine',
#   'Mississippi',
#   'Ohio',
#   'Tennessee',
#   'West Virginia'],
#  'Haralson': ['Georgia'],
#  'Harris': ['Georgia', 'Texas'],
#  'Hart': ['Georgia', 'Kentucky'],
#  'Heard': ['Georgia'],
#  'Irwin': ['Georgia'],
#  'Jasper': ['Georgia', 'Iowa', 'Missouri', 'South Carolina', 'Texas'],
#  'Jeff Davis': ['Georgia', 'Texas'],
#  'Jones': ['Georgia', 'Mississippi', 'Texas'],
#  'Lanier': ['Georgia'],
#  'Laurens': ['Georgia', 'South Carolina'],
#  'Long': ['Georgia'],
#  'Lumpkin': ['Georgia'],
#  'McDuffie': ['Georgia'],
#  'McIntosh': ['Georgia', 'Oklahoma'],
#  'Meriwether': ['Georgia'],
#  'Mitchell': ['Georgia', 'Iowa', 'Kansas', 'Texas'],
#  'Murray': ['Georgia', 'Minnesota', 'Oklahoma'],
#  'Muscogee': ['Georgia'],
#  'Oconee': ['Georgia', 'South Carolina'],
#  'Oglethorpe': ['Georgia'],
#  'Paulding': ['Georgia', 'Ohio'],
#  'Peach': ['Georgia'],
#  'Pierce': ['Georgia', 'Nebraska', 'Washington', 'Wisconsin'],
#  'Quitman': ['Georgia'],
#  'Rabun': ['Georgia'],
#  'Richmond': ['Georgia', 'New York', 'North Carolina', 'Virginia'],
#  'Rockdale': ['Georgia'],
#  'Schley': ['Georgia'],
#  'Screven': ['Georgia'],
#  'Spalding': ['Georgia'],
#  'Stephens': ['Georgia', 'Oklahoma', 'Texas'],
#  'Stewart': ['Georgia', 'Tennessee'],
#  'Talbot': ['Georgia', 'Maryland'],
#  'Tattnall': ['Georgia'],
#  'Telfair': ['Georgia'],
#  'Terrell': ['Georgia'],
#  'Thomas': ['Georgia', 'Kansas'],
#  'Tift': ['Georgia'],
#  'Toombs': ['Georgia'],
#  'Towns': ['Georgia'],
#  'Treutlen': ['Georgia'],
#  'Troup': ['Georgia'],
#  'Turner': ['Georgia', 'South Dakota'],
#  'Twiggs': ['Georgia'],
#  'Upson': ['Georgia'],
#  'Ware': ['Georgia'],
#  'Warren': ['Georgia',
#   'Illinois',
#   'Iowa',
#   'Kentucky',
#   'Mississippi',
#   'Missouri',
#   'New Jersey',
#   'New York',
#   'North Carolina',
#   'Ohio',
#   'Pennsylvania',
#   'Tennessee',
#   'Virginia'],
#  'Wayne': ['Georgia',
#   'Illinois',
#   'Iowa',
#   'Kentucky',
#   'Michigan',
#   'Missouri',
#   'New York',
#   'North Carolina',
#   'Ohio',
#   'Pennsylvania',
#   'Tennessee',
#   'West Virginia'],
#  'Webster': ['Georgia',
#   'Iowa',
#   'Kentucky',
#   'Louisiana',
#   'Missouri',
#   'Nebraska'],
#  'Wheeler': ['Georgia', 'Texas'],
#  'Whitfield': ['Georgia'],
#  'Wilkes': ['Georgia', 'North Carolina'],
#  'Wilkinson': ['Georgia'],
#  'Worth': ['Georgia', 'Iowa', 'Missouri'],
#  'Hawaii': ['Hawaii'],
#  'Honolulu': ['Hawaii'],
#  'Kauai': ['Hawaii'],
#  'Maui': ['Hawaii'],
#  'Ada': ['Idaho'],
#  'Bannock': ['Idaho'],
#  'Bear Lake': ['Idaho'],
#  'Benewah': ['Idaho'],
#  'Bingham': ['Idaho'],
#  'Blaine': ['Idaho', 'Montana'],
#  'Boise': ['Idaho'],
#  'Bonner': ['Idaho'],
#  'Bonneville': ['Idaho'],
#  'Boundary': ['Idaho'],
#  'Canyon': ['Idaho'],
#  'Caribou': ['Idaho'],
#  'Cassia': ['Idaho'],
#  'Clearwater': ['Idaho', 'Minnesota'],
#  'Gem': ['Idaho'],
#  'Gooding': ['Idaho'],
#  'Idaho': ['Idaho'],
#  'Jerome': ['Idaho'],
#  'Kootenai': ['Idaho'],
#  'Latah': ['Idaho'],
#  'Lemhi': ['Idaho'],
#  'Lewis': ['Idaho',
#   'Kentucky',
#   'Missouri',
#   'New York',
#   'Tennessee',
#   'Washington',
#   'West Virginia'],
#  'Minidoka': ['Idaho'],
#  'Nez Perce': ['Idaho'],
#  'Oneida': ['Idaho', 'New York', 'Wisconsin'],
#  'Owyhee': ['Idaho'],
#  'Payette': ['Idaho'],
#  'Power': ['Idaho'],
#  'Shoshone': ['Idaho'],
#  'Teton': ['Idaho', 'Montana'],
#  'Twin Falls': ['Idaho'],
#  'Valley': ['Idaho', 'Montana', 'Nebraska'],
#  'Alexander': ['Illinois', 'North Carolina'],
#  'Bond': ['Illinois'],
#  'Brown': ['Illinois',
#   'Indiana',
#   'Kansas',
#   'Minnesota',
#   'Nebraska',
#   'Ohio',
#   'South Dakota',
#   'Texas',
#   'Wisconsin'],
#  'Bureau': ['Illinois'],
#  'Cass': ['Illinois',
#   'Indiana',
#   'Iowa',
#   'Michigan',
#   'Minnesota',
#   'Missouri',
#   'Nebraska',
#   'North Dakota',
#   'Texas'],
#  'Champaign': ['Illinois', 'Ohio'],
#  'Christian': ['Illinois', 'Kentucky', 'Missouri'],
#  'Clinton': ['Illinois',
#   'Indiana',
#   'Iowa',
#   'Kentucky',
#   'Michigan',
#   'Missouri',
#   'New York',
#   'Ohio',
#   'Pennsylvania'],
#  'Coles': ['Illinois'],
#  'Cumberland': ['Illinois',
#   'Kentucky',
#   'Maine',
#   'New Jersey',
#   'North Carolina',
#   'Pennsylvania',
#   'Tennessee',
#   'Virginia'],
#  'De Witt': ['Illinois'],
#  'DuPage': ['Illinois'],
#  'Edgar': ['Illinois'],
#  'Ford': ['Illinois', 'Kansas'],
#  'Gallatin': ['Illinois', 'Kentucky', 'Montana'],
#  'Grundy': ['Illinois', 'Iowa', 'Missouri', 'Tennessee'],
#  'Hardin': ['Illinois', 'Iowa', 'Kentucky', 'Ohio', 'Tennessee', 'Texas'],
#  'Iroquois': ['Illinois'],
#  'Jersey': ['Illinois'],
#  'Jo Daviess': ['Illinois'],
#  'Kane': ['Illinois', 'Utah'],
#  'Kankakee': ['Illinois'],
#  'Kendall': ['Illinois', 'Texas'],
#  'Knox': ['Illinois',
#   'Indiana',
#   'Kentucky',
#   'Maine',
#   'Missouri',
#   'Nebraska',
#   'Ohio',
#   'Tennessee',
#   'Texas'],
#  'LaSalle': ['Illinois'],
#  'Livingston': ['Illinois',
#   'Kentucky',
#   'Louisiana',
#   'Michigan',
#   'Missouri',
#   'New York'],
#  'McDonough': ['Illinois'],
#  'McHenry': ['Illinois'],
#  'McLean': ['Illinois', 'Kentucky'],
#  'Macoupin': ['Illinois'],
#  'Mason': ['Illinois',
#   'Kentucky',
#   'Michigan',
#   'Texas',
#   'Washington',
#   'West Virginia'],
#  'Massac': ['Illinois'],
#  'Menard': ['Illinois', 'Texas'],
#  'Mercer': ['Illinois',
#   'Kentucky',
#   'Missouri',
#   'New Jersey',
#   'Ohio',
#   'Pennsylvania',
#   'West Virginia'],
#  'Ogle': ['Illinois'],
#  'Peoria': ['Illinois'],
#  'Piatt': ['Illinois'],
#  'Richland': ['Illinois',
#   'Louisiana',
#   'Montana',
#   'North Dakota',
#   'Ohio',
#   'South Carolina',
#   'Wisconsin'],
#  'Rock Island': ['Illinois'],
#  'Sangamon': ['Illinois'],
#  'Schuyler': ['Illinois', 'Missouri', 'New York'],
#  'Stark': ['Illinois', 'North Dakota', 'Ohio'],
#  'Stephenson': ['Illinois'],
#  'Tazewell': ['Illinois', 'Virginia'],
#  'Vermilion': ['Illinois', 'Louisiana'],
#  'Wabash': ['Illinois', 'Indiana'],
#  'Whiteside': ['Illinois'],
#  'Will': ['Illinois'],
#  'Williamson': ['Illinois', 'Tennessee', 'Texas'],
#  'Winnebago': ['Illinois', 'Iowa', 'Wisconsin'],
#  'Woodford': ['Illinois', 'Kentucky'],
#  'Allen': ['Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Ohio'],
#  'Bartholomew': ['Indiana'],
#  'Blackford': ['Indiana'],
#  'Daviess': ['Indiana', 'Kentucky', 'Missouri'],
#  'Delaware': ['Indiana',
#   'Iowa',
#   'New York',
#   'Ohio',
#   'Oklahoma',
#   'Pennsylvania'],
#  'Dubois': ['Indiana'],
#  'Elkhart': ['Indiana'],
#  'Gibson': ['Indiana', 'Tennessee'],
#  'Harrison': ['Indiana',
#   'Iowa',
#   'Kentucky',
#   'Mississippi',
#   'Missouri',
#   'Ohio',
#   'Texas',
#   'West Virginia'],
#  'Hendricks': ['Indiana'],
#  'Huntington': ['Indiana'],
#  'Jay': ['Indiana'],
#  'Jennings': ['Indiana'],
#  'Kosciusko': ['Indiana'],
#  'LaGrange': ['Indiana'],
#  'LaPorte': ['Indiana'],
#  'Miami': ['Indiana', 'Kansas', 'Ohio'],
#  'Noble': ['Indiana', 'Ohio', 'Oklahoma'],
#  'Parke': ['Indiana'],
#  'Porter': ['Indiana'],
#  'Posey': ['Indiana'],
#  'Ripley': ['Indiana', 'Missouri'],
#  'St. Joseph': ['Indiana', 'Michigan'],
#  'Starke': ['Indiana'],
#  'Steuben': ['Indiana', 'New York'],
#  'Sullivan': ['Indiana',
#   'Missouri',
#   'New Hampshire',
#   'New York',
#   'Pennsylvania',
#   'Tennessee'],
#  'Tippecanoe': ['Indiana'],
#  'Tipton': ['Indiana', 'Tennessee'],
#  'Vanderburgh': ['Indiana'],
#  'Vigo': ['Indiana'],
#  'Warrick': ['Indiana'],
#  'Wells': ['Indiana'],
#  'Adair': ['Iowa', 'Kentucky', 'Missouri', 'Oklahoma'],
#  'Allamakee': ['Iowa'],
#  'Appanoose': ['Iowa'],
#  'Audubon': ['Iowa'],
#  'Black Hawk': ['Iowa'],
#  'Bremer': ['Iowa'],
#  'Buchanan': ['Iowa', 'Missouri', 'Virginia'],
#  'Buena Vista': ['Iowa'],
#  'Cedar': ['Iowa', 'Missouri', 'Nebraska'],
#  'Cerro Gordo': ['Iowa'],
#  'Chickasaw': ['Iowa'],
#  'Davis': ['Iowa', 'Utah'],
#  'Des Moines': ['Iowa'],
#  'Dickinson': ['Iowa', 'Kansas'],
#  'Dubuque': ['Iowa'],
#  'Emmet': ['Iowa', 'Michigan'],
#  'Guthrie': ['Iowa'],
#  'Ida': ['Iowa'],
#  'Iowa': ['Iowa', 'Wisconsin'],
#  'Keokuk': ['Iowa'],
#  'Kossuth': ['Iowa'],
#  'Linn': ['Iowa', 'Kansas', 'Missouri', 'Oregon'],
#  'Louisa': ['Iowa', 'Virginia'],
#  'Lucas': ['Iowa', 'Ohio'],
#  'Lyon': ['Iowa', 'Kansas', 'Kentucky', 'Minnesota', 'Nevada'],
#  'Mahaska': ['Iowa'],
#  'Mills': ['Iowa', 'Texas'],
#  'Monona': ['Iowa'],
#  'Muscatine': ['Iowa'],
#  "O'Brien": ['Iowa'],
#  'Page': ['Iowa', 'Virginia'],
#  'Palo Alto': ['Iowa'],
#  'Plymouth': ['Iowa', 'Massachusetts'],
#  'Pocahontas': ['Iowa', 'West Virginia'],
#  'Pottawattamie': ['Iowa'],
#  'Poweshiek': ['Iowa'],
#  'Ringgold': ['Iowa'],
#  'Sac': ['Iowa'],
#  'Sioux': ['Iowa'],
#  'Story': ['Iowa'],
#  'Tama': ['Iowa'],
#  'Wapello': ['Iowa'],
#  'Winneshiek': ['Iowa'],
#  'Woodbury': ['Iowa'],
#  'Wright': ['Iowa', 'Minnesota', 'Missouri'],
#  'Anderson': ['Kansas', 'Kentucky', 'South Carolina', 'Tennessee', 'Texas'],
#  'Atchison': ['Kansas', 'Missouri'],
#  'Barber': ['Kansas'],
#  'Barton': ['Kansas', 'Missouri'],
#  'Bourbon': ['Kansas', 'Kentucky'],
#  'Chase': ['Kansas', 'Nebraska'],
#  'Cloud': ['Kansas'],
#  'Coffey': ['Kansas'],
#  'Cowley': ['Kansas'],
#  'Doniphan': ['Kansas'],
#  'Edwards': ['Kansas', 'Texas'],
#  'Elk': ['Kansas', 'Pennsylvania'],
#  'Ellis': ['Kansas', 'Texas'],
#  'Ellsworth': ['Kansas'],
#  'Finney': ['Kansas'],
#  'Geary': ['Kansas'],
#  'Gray': ['Kansas', 'Texas'],
#  'Greenwood': ['Kansas', 'South Carolina'],
#  'Harper': ['Kansas'],
#  'Harvey': ['Kansas'],
#  'Haskell': ['Kansas', 'Oklahoma', 'Texas'],
#  'Hodgeman': ['Kansas'],
#  'Kearny': ['Kansas'],
#  'Kingman': ['Kansas'],
#  'Kiowa': ['Kansas'],
#  'Labette': ['Kansas'],
#  'Leavenworth': ['Kansas'],
#  'McPherson': ['Kansas', 'South Dakota'],
#  'Morris': ['Kansas', 'New Jersey', 'Texas'],
#  'Morton': ['Kansas', 'North Dakota'],
#  'Nemaha': ['Kansas', 'Nebraska'],
#  'Neosho': ['Kansas'],
#  'Ness': ['Kansas'],
#  'Norton': ['Kansas'],
#  'Osage': ['Kansas', 'Missouri', 'Oklahoma'],
#  'Osborne': ['Kansas'],
#  'Ottawa': ['Kansas', 'Michigan', 'Ohio', 'Oklahoma'],
#  'Pawnee': ['Kansas', 'Nebraska', 'Oklahoma'],
#  'Pottawatomie': ['Kansas', 'Oklahoma'],
#  'Pratt': ['Kansas'],
#  'Rawlins': ['Kansas'],
#  'Reno': ['Kansas'],
#  'Republic': ['Kansas'],
#  'Rice': ['Kansas', 'Minnesota'],
#  'Riley': ['Kansas'],
#  'Rooks': ['Kansas'],
#  'Rush': ['Kansas'],
#  'Seward': ['Kansas', 'Nebraska'],
#  'Shawnee': ['Kansas'],
#  'Sheridan': ['Kansas', 'Montana', 'Nebraska', 'Wyoming'],
#  'Sherman': ['Kansas', 'Nebraska', 'Oregon', 'Texas'],
#  'Smith': ['Kansas', 'Tennessee', 'Texas'],
#  'Stafford': ['Kansas', 'Virginia'],
#  'Stevens': ['Kansas', 'Minnesota', 'Washington'],
#  'Sumner': ['Kansas', 'Tennessee'],
#  'Trego': ['Kansas'],
#  'Wabaunsee': ['Kansas'],
#  'Wichita': ['Kansas', 'Texas'],
#  'Wilson': ['Kansas', 'North Carolina', 'Tennessee', 'Texas'],
#  'Woodson': ['Kansas'],
#  'Wyandotte': ['Kansas'],
#  'Ballard': ['Kentucky'],
#  'Barren': ['Kentucky'],
#  'Bath': ['Kentucky', 'Virginia'],
#  'Bell': ['Kentucky', 'Texas'],
#  'Boyd': ['Kentucky'],
#  'Boyle': ['Kentucky'],
#  'Bracken': ['Kentucky'],
#  'Breathitt': ['Kentucky'],
#  'Breckinridge': ['Kentucky'],
#  'Bullitt': ['Kentucky'],
#  'Caldwell': ['Kentucky', 'Louisiana', 'Missouri', 'North Carolina', 'Texas'],
#  'Calloway': ['Kentucky'],
#  'Campbell': ['Kentucky', 'Tennessee', 'Virginia', 'Wyoming'],
#  'Carlisle': ['Kentucky'],
#  'Carter': ['Kentucky', 'Missouri', 'Oklahoma', 'Tennessee'],
#  'Casey': ['Kentucky'],
#  'Edmonson': ['Kentucky'],
#  'Elliott': ['Kentucky'],
#  'Estill': ['Kentucky'],
#  'Fleming': ['Kentucky'],
#  'Garrard': ['Kentucky'],
#  'Graves': ['Kentucky'],
#  'Grayson': ['Kentucky', 'Texas', 'Virginia'],
#  'Green': ['Kentucky', 'Wisconsin'],
#  'Greenup': ['Kentucky'],
#  'Harlan': ['Kentucky'],
#  'Henderson': ['Kentucky', 'North Carolina', 'Tennessee', 'Texas'],
#  'Hickman': ['Kentucky', 'Tennessee'],
#  'Hopkins': ['Kentucky', 'Texas'],
#  'Jessamine': ['Kentucky'],
#  'Kenton': ['Kentucky'],
#  'Knott': ['Kentucky'],
#  'Larue': ['Kentucky'],
#  'Laurel': ['Kentucky'],
#  'Leslie': ['Kentucky'],
#  'Letcher': ['Kentucky'],
#  'McCracken': ['Kentucky'],
#  'McCreary': ['Kentucky'],
#  'Magoffin': ['Kentucky'],
#  'Meade': ['Kentucky', 'South Dakota'],
#  'Menifee': ['Kentucky'],
#  'Metcalfe': ['Kentucky'],
#  'Muhlenberg': ['Kentucky'],
#  'Nelson': ['Kentucky', 'Virginia'],
#  'Nicholas': ['Kentucky', 'West Virginia'],
#  'Ohio': ['Kentucky', 'West Virginia'],
#  'Oldham': ['Kentucky', 'Texas'],
#  'Owen': ['Kentucky'],
#  'Owsley': ['Kentucky'],
#  'Pendleton': ['Kentucky'],
#  'Powell': ['Kentucky', 'Montana'],
#  'Robertson': ['Kentucky', 'Tennessee', 'Texas'],
#  'Rockcastle': ['Kentucky'],
#  'Rowan': ['Kentucky', 'North Carolina'],
#  'Simpson': ['Kentucky'],
#  'Spencer': ['Kentucky'],
#  'Todd': ['Kentucky', 'Minnesota'],
#  'Trigg': ['Kentucky'],
#  'Trimble': ['Kentucky'],
#  'Whitley': ['Kentucky'],
#  'Wolfe': ['Kentucky'],
#  'Acadia': ['Louisiana'],
#  'Ascension': ['Louisiana'],
#  'Assumption': ['Louisiana'],
#  'Avoyelles': ['Louisiana'],
#  'Beauregard': ['Louisiana'],
#  'Bienville': ['Louisiana'],
#  'Bossier': ['Louisiana'],
#  'Caddo': ['Louisiana', 'Oklahoma'],
#  'Calcasieu': ['Louisiana'],
#  'Cameron': ['Louisiana', 'Pennsylvania', 'Texas'],
#  'Catahoula': ['Louisiana'],
#  'Claiborne': ['Louisiana', 'Mississippi', 'Tennessee'],
#  'Concordia': ['Louisiana'],
#  'De Soto': ['Louisiana'],
#  'East Baton Rouge': ['Louisiana'],
#  'East Carroll': ['Louisiana'],
#  'East Feliciana': ['Louisiana'],
#  'Evangeline': ['Louisiana'],
#  'Iberia': ['Louisiana'],
#  'Iberville': ['Louisiana'],
#  'Jefferson Davis': ['Louisiana'],
#  'Lafourche': ['Louisiana'],
#  'La Salle': ['Louisiana', 'Texas'],
#  'Morehouse': ['Louisiana'],
#  'Natchitoches': ['Louisiana'],
#  'Orleans': ['Louisiana', 'New York', 'Vermont'],
#  'Plaquemines': ['Louisiana'],
#  'Pointe Coupee': ['Louisiana'],
#  'Rapides': ['Louisiana'],
#  'Red River': ['Louisiana', 'Texas'],
#  'Sabine': ['Louisiana', 'Texas'],
#  'St. Bernard': ['Louisiana'],
#  'St. Charles': ['Louisiana', 'Missouri'],
#  'St. Helena': ['Louisiana'],
#  'St. James': ['Louisiana'],
#  'St. John the Baptist': ['Louisiana'],
#  'St. Landry': ['Louisiana'],
#  'St. Martin': ['Louisiana'],
#  'St. Mary': ['Louisiana'],
#  'St. Tammany': ['Louisiana'],
#  'Tangipahoa': ['Louisiana'],
#  'Tensas': ['Louisiana'],
#  'Terrebonne': ['Louisiana'],
#  'Vernon': ['Louisiana', 'Missouri', 'Wisconsin'],
#  'West Baton Rouge': ['Louisiana'],
#  'West Carroll': ['Louisiana'],
#  'West Feliciana': ['Louisiana'],
#  'Winn': ['Louisiana'],
#  'Androscoggin': ['Maine'],
#  'Aroostook': ['Maine'],
#  'Kennebec': ['Maine'],
#  'Oxford': ['Maine'],
#  'Penobscot': ['Maine'],
#  'Sagadahoc': ['Maine'],
#  'Somerset': ['Maine', 'Maryland', 'New Jersey', 'Pennsylvania'],
#  'Waldo': ['Maine'],
#  'York': ['Maine', 'Nebraska', 'Pennsylvania', 'South Carolina', 'Virginia'],
#  'Allegany': ['Maryland', 'New York'],
#  'Anne Arundel': ['Maryland'],
#  'Baltimore': ['Maryland'],
#  'Calvert': ['Maryland'],
#  'Caroline': ['Maryland', 'Virginia'],
#  'Cecil': ['Maryland'],
#  'Charles': ['Maryland'],
#  'Dorchester': ['Maryland', 'South Carolina'],
#  'Frederick': ['Maryland', 'Virginia'],
#  'Garrett': ['Maryland'],
#  'Harford': ['Maryland'],
#  "Prince George's": ['Maryland'],
#  "Queen Anne's": ['Maryland'],
#  "St. Mary's": ['Maryland'],
#  'Wicomico': ['Maryland'],
#  'Worcester': ['Maryland', 'Massachusetts'],
#  'Baltimore City': ['Maryland'],
#  'Barnstable': ['Massachusetts'],
#  'Berkshire': ['Massachusetts'],
#  'Bristol': ['Massachusetts', 'Rhode Island'],
#  'Essex': ['Massachusetts', 'New Jersey', 'New York', 'Virginia'],
#  'Hampden': ['Massachusetts'],
#  'Hampshire': ['Massachusetts', 'West Virginia'],
#  'Nantucket': ['Massachusetts'],
#  'Norfolk': ['Massachusetts'],
#  'Suffolk': ['Massachusetts', 'New York'],
#  'Alcona': ['Michigan'],
#  'Alger': ['Michigan'],
#  'Allegan': ['Michigan'],
#  'Alpena': ['Michigan'],
#  'Antrim': ['Michigan'],
#  'Arenac': ['Michigan'],
#  'Baraga': ['Michigan'],
#  'Barry': ['Michigan', 'Missouri'],
#  'Benzie': ['Michigan'],
#  'Branch': ['Michigan'],
#  'Charlevoix': ['Michigan'],
#  'Cheboygan': ['Michigan'],
#  'Chippewa': ['Michigan', 'Minnesota', 'Wisconsin'],
#  'Clare': ['Michigan'],
#  'Eaton': ['Michigan'],
#  'Genesee': ['Michigan', 'New York'],
#  'Gladwin': ['Michigan'],
#  'Gogebic': ['Michigan'],
#  'Grand Traverse': ['Michigan'],
#  'Gratiot': ['Michigan'],
#  'Hillsdale': ['Michigan'],
#  'Houghton': ['Michigan'],
#  'Huron': ['Michigan'],
#  'Ingham': ['Michigan'],
#  'Ionia': ['Michigan'],
#  'Iosco': ['Michigan'],
#  'Iron': ['Michigan', 'Missouri', 'Utah', 'Wisconsin'],
#  'Isabella': ['Michigan'],
#  'Kalamazoo': ['Michigan'],
#  'Kalkaska': ['Michigan'],
#  'Keweenaw': ['Michigan'],
#  'Lapeer': ['Michigan'],
#  'Leelanau': ['Michigan'],
#  'Lenawee': ['Michigan'],
#  'Luce': ['Michigan'],
#  'Mackinac': ['Michigan'],
#  'Macomb': ['Michigan'],
#  'Manistee': ['Michigan'],
#  'Marquette': ['Michigan', 'Wisconsin'],
#  'Mecosta': ['Michigan'],
#  'Menominee': ['Michigan', 'Wisconsin'],
#  'Midland': ['Michigan', 'Texas'],
#  'Missaukee': ['Michigan'],
#  'Montcalm': ['Michigan'],
#  'Montmorency': ['Michigan'],
#  'Muskegon': ['Michigan'],
#  'Newaygo': ['Michigan'],
#  'Oakland': ['Michigan'],
#  'Oceana': ['Michigan'],
#  'Ogemaw': ['Michigan'],
#  'Ontonagon': ['Michigan'],
#  'Oscoda': ['Michigan'],
#  'Otsego': ['Michigan', 'New York'],
#  'Presque Isle': ['Michigan'],
#  'Roscommon': ['Michigan'],
#  'Saginaw': ['Michigan'],
#  'Sanilac': ['Michigan'],
#  'Shiawassee': ['Michigan'],
#  'Tuscola': ['Michigan'],
#  'Washtenaw': ['Michigan'],
#  'Wexford': ['Michigan'],
#  'Aitkin': ['Minnesota'],
#  'Anoka': ['Minnesota'],
#  'Becker': ['Minnesota'],
#  'Beltrami': ['Minnesota'],
#  'Big Stone': ['Minnesota'],
#  'Blue Earth': ['Minnesota'],
#  'Carlton': ['Minnesota'],
#  'Carver': ['Minnesota'],
#  'Chisago': ['Minnesota'],
#  'Cottonwood': ['Minnesota'],
#  'Crow Wing': ['Minnesota'],
#  'Dakota': ['Minnesota', 'Nebraska'],
#  'Faribault': ['Minnesota'],
#  'Fillmore': ['Minnesota', 'Nebraska'],
#  'Freeborn': ['Minnesota'],
#  'Goodhue': ['Minnesota'],
#  'Hennepin': ['Minnesota'],
#  'Hubbard': ['Minnesota'],
#  'Isanti': ['Minnesota'],
#  'Itasca': ['Minnesota'],
#  'Kanabec': ['Minnesota'],
#  'Kandiyohi': ['Minnesota'],
#  'Kittson': ['Minnesota'],
#  'Koochiching': ['Minnesota'],
#  'Lac qui Parle': ['Minnesota'],
#  'Lake of the Woods': ['Minnesota'],
#  'Le Sueur': ['Minnesota'],
#  'McLeod': ['Minnesota'],
#  'Mahnomen': ['Minnesota'],
#  'Meeker': ['Minnesota'],
#  'Mille Lacs': ['Minnesota'],
#  'Morrison': ['Minnesota'],
#  'Mower': ['Minnesota'],
#  'Nicollet': ['Minnesota'],
#  'Nobles': ['Minnesota'],
#  'Norman': ['Minnesota'],
#  'Olmsted': ['Minnesota'],
#  'Otter Tail': ['Minnesota'],
#  'Pennington': ['Minnesota', 'South Dakota'],
#  'Pine': ['Minnesota'],
#  'Pipestone': ['Minnesota'],
#  'Ramsey': ['Minnesota', 'North Dakota'],
#  'Red Lake': ['Minnesota'],
#  'Redwood': ['Minnesota'],
#  'Renville': ['Minnesota'],
#  'Rock': ['Minnesota', 'Wisconsin'],
#  'Roseau': ['Minnesota'],
#  'St. Louis': ['Minnesota', 'Missouri'],
#  'Sherburne': ['Minnesota'],
#  'Sibley': ['Minnesota'],
#  'Stearns': ['Minnesota'],
#  'Steele': ['Minnesota'],
#  'Swift': ['Minnesota'],
#  'Traverse': ['Minnesota'],
#  'Wabasha': ['Minnesota'],
#  'Wadena': ['Minnesota'],
#  'Waseca': ['Minnesota'],
#  'Watonwan': ['Minnesota'],
#  'Wilkin': ['Minnesota'],
#  'Winona': ['Minnesota'],
#  'Yellow Medicine': ['Minnesota'],
#  'Forrest': ['Mississippi'],
#  'George': ['Mississippi'],
#  'Hinds': ['Mississippi'],
#  'Itawamba': ['Mississippi'],
#  'Kemper': ['Mississippi'],
#  'Leflore': ['Mississippi'],
#  'Oktibbeha': ['Mississippi'],
#  'Panola': ['Mississippi', 'Texas'],
#  'Rankin': ['Mississippi'],
#  'Tishomingo': ['Mississippi'],
#  'Tunica': ['Mississippi'],
#  'Andrew': ['Missouri'],
#  'Audrain': ['Missouri'],
#  'Bates': ['Missouri'],
#  'Bollinger': ['Missouri'],
#  'Callaway': ['Missouri'],
#  'Cape Girardeau': ['Missouri'],
#  'Chariton': ['Missouri'],
#  'Cole': ['Missouri'],
#  'Cooper': ['Missouri'],
#  'Dent': ['Missouri'],
#  'Dunklin': ['Missouri'],
#  'Gasconade': ['Missouri'],
#  'Gentry': ['Missouri'],
#  'Hickory': ['Missouri'],
#  'Holt': ['Missouri', 'Nebraska'],
#  'Howell': ['Missouri'],
#  'Laclede': ['Missouri'],
#  'McDonald': ['Missouri'],
#  'Maries': ['Missouri'],
#  'Moniteau': ['Missouri'],
#  'New Madrid': ['Missouri'],
#  'Nodaway': ['Missouri'],
#  'Oregon': ['Missouri'],
#  'Ozark': ['Missouri'],
#  'Pemiscot': ['Missouri'],
#  'Pettis': ['Missouri'],
#  'Phelps': ['Missouri', 'Nebraska'],
#  'Platte': ['Missouri', 'Nebraska', 'Wyoming'],
#  'Ralls': ['Missouri'],
#  'Ray': ['Missouri'],
#  'Reynolds': ['Missouri'],
#  'Ste. Genevieve': ['Missouri'],
#  'St. Francois': ['Missouri'],
#  'Scotland': ['Missouri', 'North Carolina'],
#  'Shannon': ['Missouri'],
#  'Stoddard': ['Missouri'],
#  'Taney': ['Missouri'],
#  'Texas': ['Missouri', 'Oklahoma'],
#  'St. Louis City': ['Missouri'],
#  'Beaverhead': ['Montana'],
#  'Big Horn': ['Montana', 'Wyoming'],
#  'Broadwater': ['Montana'],
#  'Carbon': ['Montana', 'Pennsylvania', 'Utah', 'Wyoming'],
#  'Cascade': ['Montana'],
#  'Daniels': ['Montana'],
#  'Deer Lodge': ['Montana'],
#  'Fallon': ['Montana'],
#  'Fergus': ['Montana'],
#  'Flathead': ['Montana'],
#  'Glacier': ['Montana'],
#  'Granite': ['Montana'],
#  'Hill': ['Montana', 'Texas'],
#  'Judith Basin': ['Montana'],
#  'Lewis and Clark': ['Montana'],
#  'McCone': ['Montana'],
#  'Meagher': ['Montana'],
#  'Mineral': ['Montana', 'Nevada', 'West Virginia'],
#  'Missoula': ['Montana'],
#  'Musselshell': ['Montana'],
#  'Pondera': ['Montana'],
#  'Powder River': ['Montana'],
#  'Ravalli': ['Montana'],
#  'Roosevelt': ['Montana', 'New Mexico'],
#  'Rosebud': ['Montana'],
#  'Sanders': ['Montana'],
#  'Silver Bow': ['Montana'],
#  'Stillwater': ['Montana'],
#  'Sweet Grass': ['Montana'],
#  'Toole': ['Montana'],
#  'Wheatland': ['Montana'],
#  'Yellowstone': ['Montana'],
#  'Antelope': ['Nebraska'],
#  'Box Butte': ['Nebraska'],
#  'Buffalo': ['Nebraska', 'Wisconsin'],
#  'Burt': ['Nebraska'],
#  'Cherry': ['Nebraska'],
#  'Cuming': ['Nebraska'],
#  'Dawes': ['Nebraska'],
#  'Deuel': ['Nebraska', 'South Dakota'],
#  'Dixon': ['Nebraska'],
#  'Furnas': ['Nebraska'],
#  'Gage': ['Nebraska'],
#  'Gosper': ['Nebraska'],
#  'Hitchcock': ['Nebraska'],
#  'Kearney': ['Nebraska'],
#  'Keith': ['Nebraska'],
#  'Kimball': ['Nebraska'],
#  'Lancaster': ['Nebraska', 'Pennsylvania', 'South Carolina', 'Virginia'],
#  'Merrick': ['Nebraska'],
#  'Morrill': ['Nebraska'],
#  'Otoe': ['Nebraska'],
#  'Perkins': ['Nebraska', 'South Dakota'],
#  'Red Willow': ['Nebraska'],
#  'Richardson': ['Nebraska'],
#  'Sarpy': ['Nebraska'],
#  ...}

# %%
mutual_counties = {}

# append mutual county keys: [] to mutual_counties 
for key in county_stats_counties:
    if key in sociohealth_counties:
        mutual_counties[key] = []

# for mutual key, only add append states that are in both
for county in mutual_counties:
    mutual_counties[county] = list(set(county_stats_counties[county]).intersection(sociohealth_counties[county]))
    
# delete rows in county_stats_df that don't have county and state in mutual_counties dict
for i in range(len(county_stats_df['county'])):
    county, state = county_stats_df['county'][i], county_stats_df['state'][i]
    # if county is not a dictionary key in mutuals, delete row
    if (county not in mutual_counties) or (state not in mutual_counties[county]):
        county_stats_df = county_stats_df.drop(index=i)
    # else, pass
    else:
        pass

# delete rows in sociohealth_df that don't have county and state in mutual_counties dict
for i in range(len(sociohealth_df['county'])):
    county, state = sociohealth_df['county'][i], sociohealth_df['state'][i]
    # if county is not a dictionary key in mutuals, delete row
    if (county not in mutual_counties) or (state not in mutual_counties[county]):
        sociohealth_df = sociohealth_df.drop(index=i)
    # else, pass
    else:
        pass

# %%
assert(len(county_stats_df['state']) == len(sociohealth_df['state']))

# %%
county_stats_df.to_sql(name='county_statistics', con=engine, if_exists='append', index=False)
sociohealth_df.to_sql(name='county_sociohealth_data', con=engine, if_exists='append', index=False)
